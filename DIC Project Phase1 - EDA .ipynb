# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
df = pd.read_csv('DICDataCleaned.csv')
df
# Out:
#       Unnamed: 0  Accelarations  Fetal Movements  Uterine Contractions  \
# 0              1       0.000000         0.000000              0.000000
# 1              2       0.153846         0.000000              0.173913
# 2              3       0.076923         0.000000              0.217391
# 3              4       0.076923         0.000000              0.260870
# 4              5       0.153846         0.000000              0.217391
# ...          ...            ...              ...                   ...
# 2111        2122       0.000000         0.000000              0.260870
# 2112        2123       0.038462         0.000000              0.391304
# 2113        2124       0.038462         0.000000              0.304348
# 2114        2125       0.038462         0.000000              0.391304
# 2115        2126       0.038462         0.001773              0.217391
#
#       FHR Baseline  Abnormal Short-term Variability  Mean STV  \
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0  Accelarations  Fetal Movements  Uterine Contractions  \
# count  2116.000000    2116.000000      2116.000000           2116.000000
# mean   1065.202741       0.104988         0.012881              0.159715
# std     614.109383       0.137149         0.065975              0.123712
# min       1.000000       0.000000         0.000000              0.000000
# 25%     533.750000       0.000000         0.000000              0.043478
# 50%    1065.500000       0.038462         0.000000              0.130435
# 75%    1597.250000       0.153846         0.003546              0.217391
# max    2126.000000       1.000000         1.000000              1.000000
#
#        FHR Baseline  Abnormal Short-term Variability     Mean STV  \
# count   2116.000000                      2116.000000  2116.000000
# mean       0.505689                         0.466560     0.166838
# std        0.182173                         0.229190     0.130036
# ...

# %%
df.plot.line('Accelarations', 'Fetal State Class', color='#0504aa')
# Out:
# <AxesSubplot:xlabel='Accelarations'>

# %%
df.hist('Accelarations',bins='auto', color='#0504aa', alpha=0.7, rwidth=0.85)
# Out:
# array([[<AxesSubplot:title={'center':'Accelarations'}>]], dtype=object)

# %%
df.hist('Decelerations',bins='auto', color='#0504aa', alpha=0.7, rwidth=0.85)
# Out:
# array([[<AxesSubplot:title={'center':'Decelerations'}>]], dtype=object)

# %%
df.hist('Fetal Movements', color='#0504aa', rwidth=0.85)
# Out:
# array([[<AxesSubplot:title={'center':'Fetal Movements'}>]], dtype=object)

# %%
df.hist('Uterine Contractions',bins='auto', color='#0504aa', alpha=0.7, rwidth=0.85)
# Out:
# array([[<AxesSubplot:title={'center':'Uterine Contractions'}>]],
#       dtype=object)

# %%
df.hist('FHR Baseline',bins='auto', color='#0504aa', alpha=0.7, rwidth=0.85)
# Out:
# array([[<AxesSubplot:title={'center':'FHR Baseline'}>]], dtype=object)

# %%
df.hist('Abnormal Short-term Variability',bins='auto', color='#0504aa', alpha=0.7, rwidth=0.85)
# Out:
# array([[<AxesSubplot:title={'center':'Abnormal Short-term Variability'}>]],
#       dtype=object)

# %%
df.hist('Mean STV',bins='auto', color='#0504aa', alpha=0.7, rwidth=0.85)
# Out:
# array([[<AxesSubplot:title={'center':'Mean STV'}>]], dtype=object)

# %%
df.hist('Abnormal Longterm Variability', color='#0504aa', alpha=0.7, rwidth=0.85)
# Out:
# array([[<AxesSubplot:title={'center':'Abnormal Longterm Variability'}>]],
#       dtype=object)

# %%
df.hist('Mean LTV', color='#0504aa', alpha=0.7, rwidth=0.85)
# Out:
# array([[<AxesSubplot:title={'center':'Mean LTV'}>]], dtype=object)

# %%
df.hist('CLASS', bins='auto', color='#0504aa', alpha=0.7, rwidth=0.85)
# Out:
# array([[<AxesSubplot:title={'center':'CLASS'}>]], dtype=object)

# %%
df.hist('Fetal State Class', bins='auto', color='#0504aa', alpha=0.7, rwidth=0.85)
# Out:
# array([[<AxesSubplot:title={'center':'Fetal State Class'}>]], dtype=object)

# %%
df.hist('Decelerations',  color='#0504aa', alpha=0.7, rwidth=0.85)
# Out:
# array([[<AxesSubplot:title={'center':'Decelerations'}>]], dtype=object)

# %%
df.boxplot(column=['Accelarations', 'Decelerations'])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column=['Mean STV', 'Mean LTV'])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column=['Abnormal Short-term Variability', 'Abnormal Longterm Variability'])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column=['Uterine Contractions','Fetal Movements','FHR Baseline'])
# Out:
# <AxesSubplot:>

# %%
 df.plot.scatter(x='Decelerations', y='Fetal State Class', c='DarkBlue')
# Out:
# <AxesSubplot:xlabel='Decelerations', ylabel='Fetal State Class'>

# %%
df['Fetal State Class'] = df['Fetal State Class'].astype(int)
df['CLASS'] = df['CLASS'].astype(int)
arr = df['Fetal State Class'].to_numpy()
arr2 = df['CLASS'].to_numpy()
arr
arr2
#plt.pie(arr)
#plt.show()
# Out:
# array([9, 6, 6, ..., 5, 5, 1])

# %%
def label_function(val):
    return f'{val / 100 * len(df):.0f}\n{val:.0f}%'

N = 50
df = pd.DataFrame({'CLASS': arr2,
                   'Fetal State Class': arr})

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 5))

df.groupby('CLASS').size().plot(kind='pie', autopct=label_function, textprops={'fontsize': 5},
                                  colors=['tomato', 'gold', 'skyblue', 'greenyellow', 'cyan', 'olive','brown','gray','pink','green'], ax=ax1)
df.groupby('Fetal State Class').size().plot(kind='pie', autopct=label_function, textprops={'fontsize': 10},
                                 colors=['violet', 'lime', 'red'], ax=ax2)
ax1.set_ylabel('According to FHR State Class Code', size=15)
ax2.set_ylabel('According to Fetal State Class', size=15)
plt.tight_layout()
plt.show()
